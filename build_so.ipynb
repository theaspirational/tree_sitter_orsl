# %%
from tree_sitter import Language

Language.build_library(
    'build/orsl.so',
    [""])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/aspirational/Documents/code/lynx/orsl/tree_sitter_orsl/build_so.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/Users/aspirational/Documents/code/lynx/orsl/tree_sitter_orsl/build_so.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from tree_sitter import Language
# ----> <a href='vscode-notebook-cell:/Users/aspirational/Documents/code/lynx/orsl/tree_sitter_orsl/build_so.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> Language.build_library(
#       <a href='vscode-notebook-cell:/Users/aspirational/Documents/code/lynx/orsl/tree_sitter_orsl/build_so.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a>     'build/orsl.so',
#       <a href='vscode-notebook-cell:/Users/aspirational/Documents/code/lynx/orsl/tree_sitter_orsl/build_so.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a>     ["tree_sitter_orsl"])
#
# ...
